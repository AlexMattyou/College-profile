# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# for VS code and Jupyter Notebook users:
# !git clone https://github.com/Mithileysh/Email-Datasets.git datasets/email
url = "datasets/email/Enron Datasets/enron_org.csv"
# Out:
# fatal: destination path 'datasets/email' already exists and is not an empty directory.

# %%
# for Google colab users:
# url = 'https://raw.githubusercontent.com/Mithileysh/Email-Datasets/master/Enron%20Datasets/enron_org.csv'

# %%
df = pd.read_csv(url)
df.sample(5)
# Out:
#                      Email_id          status
# 111  phillip.m.love@enron.com             NaN
# 8          kay.mann@enron.com        Employee
# 47      andy.zipper@enron.com  Vice President
# 60       craig.dean@enron.com          Trader
# 96    michelle.cash@enron.com        Employee

# %%
df['username'] = df['Email_id'].apply(lambda x: x.split('@')[0])
df['first_name'] = df['username'].apply(lambda x: x.split('.')[0].title())

# %%
print(df)
# Out:
#                       Email_id    status         username first_name
# 0        marie.heard@enron.com       NaN      marie.heard      Marie
# 1      mark.e.taylor@enron.com  Employee    mark.e.taylor       Mark
# 2       lindy.donoho@enron.com  Employee     lindy.donoho      Lindy
# 3          lisa.gang@enron.com       NaN        lisa.gang       Lisa
# 4      jeff.skilling@enron.com       CEO    jeff.skilling       Jeff
# ..                         ...       ...              ...        ...
# 144      tom.donohoe@enron.com  Employee      tom.donohoe        Tom
# 145  tori.kuykendall@enron.com    Trader  tori.kuykendall       Tori
# 146   tracy.geaccone@enron.com  Employee   tracy.geaccone      Tracy
# 147       j.kaminski@enron.com   Manager       j.kaminski          J
# 148    vladi.pimenov@enron.com       NaN    vladi.pimenov      Vladi
#
# [149 rows x 4 columns]

# %%
df.shape
# Out:
# (149, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Email_id    149 non-null    object
#  1   status      117 non-null    object
#  2   username    149 non-null    object
#  3   first_name  149 non-null    object
# dtypes: object(4)
# memory usage: 4.8+ KB

# %%
df.dtypes
# Out:
# Email_id      object
# status        object
# username      object
# first_name    object
# dtype: object

# %%
df.describe()
# Out:
#                      Email_id    status     username first_name
# count                     149       117          149        149
# unique                    149         9          149        110
# top     marie.heard@enron.com  Employee  marie.heard       John
# freq                        1        41            1          4

# %%
print(df.first_name.nunique())
# Out:
# 110

# %%
df.status.value_counts(dropna=False)
# Out:
# status
# Employee             41
# NaN                  32
# Vice President       23
# Director             14
# Manager              14
# Trader               13
# CEO                   4
# President             4
# Managing Director     3
# In House Lawyer       1
# Name: count, dtype: int64

# %%
sns.countplot(x='status', data=df)
plt.show()

# %%
df['status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.axis('equal')
plt.show()
