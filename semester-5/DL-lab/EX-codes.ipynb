# %%
# Step 1: Import necessary libraries
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Step 2: Define the XOR input and output
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# Step 3: Create the DNN model
model = Sequential()
model.add(Dense(4, input_dim=2, activation='relu'))  # Hidden layer with 4 neurons and ReLU activation
model.add(Dense(1, activation='sigmoid'))            # Output layer with 1 neuron and Sigmoid activation

# Step 4: Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Step 5: Train the model
model.fit(X, y, epochs=1000, verbose=0)  # Train the model for 1000 epochs, silent output

# Step 6: Evaluate the model
_, accuracy = model.evaluate(X, y)
print(f"Model Accuracy: {accuracy * 100:.2f}%")

# Step 7: Test predictions
predictions = model.predict(X)
print("Predictions:")
for i in range(len(X)):
    print(f"Input: {X[i]}, Predicted Output: {np.round(predictions[i][0])}")
# Out:
# 1/1 [==============================] - 0s 108ms/step - loss: 0.6932 - accuracy: 0.5000
# Model Accuracy: 50.00%
# 1/1 [==============================] - 0s 46ms/step
# Predictions:
# Input: [0 0], Predicted Output: 0.0
# Input: [0 1], Predicted Output: 1.0
# Input: [1 0], Predicted Output: 0.0
# Input: [1 1], Predicted Output: 1.0

# %%
# Step 1: Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Step 2: Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Step 3: Preprocess the data
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255  # Normalize and reshape
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# Step 4: One-hot encode the labels
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Step 5: Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))  # Convolutional layer
model.add(MaxPooling2D(pool_size=(2, 2)))                                # Max pooling layer
model.add(Conv2D(64, (3, 3), activation='relu'))                         # Another convolutional layer
model.add(MaxPooling2D(pool_size=(2, 2)))                                # Another max pooling layer
model.add(Flatten())                                                     # Flatten the feature maps
model.add(Dense(128, activation='relu'))                                 # Fully connected layer
model.add(Dense(10, activation='softmax'))                               # Output layer for 10 classes

# Step 6: Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Step 7: Train the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200, verbose=2)

# Step 8: Evaluate the model
scores = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {scores[1] * 100:.2f}%")

# Step 9: Make predictions and visualize
predictions = model.predict(X_test)

# Plot some sample images with their predictions
for i in range(5):
    plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"Predicted Label: {np.argmax(predictions[i])}")
    plt.show()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/5
# 300/300 - 6s - loss: 0.2585 - accuracy: 0.9254 - val_loss: 0.0679 - val_accuracy: 0.9781 - 6s/epoch - 19ms/step
# Epoch 2/5
# 300/300 - 4s - loss: 0.0659 - accuracy: 0.9793 - val_loss: 0.0454 - val_accuracy: 0.9852 - 4s/epoch - 15ms/step
# Epoch 3/5
# 300/300 - 5s - loss: 0.0467 - accuracy: 0.9854 - val_loss: 0.0460 - val_accuracy: 0.9852 - 5s/epoch - 15ms/step
# Epoch 4/5
# 300/300 - 5s - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.0526 - val_accuracy: 0.9818 - 5s/epoch - 15ms/step
# Epoch 5/5
# 300/300 - 5s - loss: 0.0291 - accuracy: 0.9908 - val_loss: 0.0397 - val_accuracy: 0.9871 - 5s/epoch - 16ms/step
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0397 - accuracy: 0.9871
# Test Accuracy: 98.71%
# 313/313 [==============================] - 1s 3ms/step

# %%
# Step 1: Import Libraries
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import to_categorical

# Step 2: Load and Preprocess Data
# For simplicity, we'll use the "Labeled Faces in the Wild" dataset from sklearn
from sklearn.datasets import fetch_lfw_people

# Load dataset
lfw_dataset = fetch_lfw_people(min_faces_per_person=100, resize=0.4)
X = lfw_dataset.images
y = lfw_dataset.target

# Preprocess data
X = X / 255.0  # Normalize pixel values
X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)  # Add channel dimension
y = to_categorical(y)  # One-hot encode labels

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: Build the CNN Model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(X.shape[1], X.shape[2], 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(y.shape[1], activation='softmax'))

# Step 4: Compile the Model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Step 5: Train the Model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Step 6: Evaluate the Model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Step 7: Test the Model on New Images
# Load a sample image from the test set and predict
sample_image = X_test[10]
sample_image_input = np.expand_dims(sample_image, axis=0)  # Expand dimensions to match model input
prediction = model.predict(sample_image_input)
predicted_label = np.argmax(prediction)

# Step 8: Display the Output
import matplotlib.pyplot as plt
plt.imshow(sample_image.reshape(X.shape[1], X.shape[2]), cmap='gray')
plt.title(f"Predicted Label: {lfw_dataset.target_names[predicted_label]}")
plt.show()
# Out:
# Epoch 1/10
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4817 - accuracy: 0.4549 - val_loss: 1.4352 - val_accuracy: 0.4649
# Epoch 2/10
# 25/25 [==============================] - 0s 13ms/step - loss: 1.4226 - accuracy: 0.4649 - val_loss: 1.3976 - val_accuracy: 0.4649
# Epoch 3/10
# 25/25 [==============================] - 0s 12ms/step - loss: 1.4173 - accuracy: 0.4649 - val_loss: 1.4022 - val_accuracy: 0.4649
# Epoch 4/10
# 25/25 [==============================] - 0s 12ms/step - loss: 1.4249 - accuracy: 0.4649 - val_loss: 1.4144 - val_accuracy: 0.4649
# Epoch 5/10
# 25/25 [==============================] - 0s 12ms/step - loss: 1.4248 - accuracy: 0.4649 - val_loss: 1.3991 - val_accuracy: 0.4649
# Epoch 6/10
# 25/25 [==============================] - 0s 11ms/step - loss: 1.4156 - accuracy: 0.4649 - val_loss: 1.3984 - val_accuracy: 0.4649
# Epoch 7/10
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample Data (Sentences and Corresponding POS Tags)
sentences = [
    "I love programming",
    "This is an example",
    "NLP is fun"
]
pos_tags = [
    "PRON VERB NOUN",
    "DET VERB DET NOUN",
    "NOUN VERB ADJ"
]

# Tokenize words and POS tags
word_tokenizer = Tokenizer()
word_tokenizer.fit_on_texts(sentences)
X = word_tokenizer.texts_to_sequences(sentences)
X = pad_sequences(X, padding='post')

pos_tokenizer = Tokenizer()
pos_tokenizer.fit_on_texts(pos_tags)
y = pos_tokenizer.texts_to_sequences(pos_tags)
y = pad_sequences(y, padding='post')

# Vocabulary sizes
word_vocab_size = len(word_tokenizer.word_index) + 1
pos_vocab_size = len(pos_tokenizer.word_index) + 1

# Model Parameters
embedding_dim = 64
lstm_units = 64

# Build the Seq2Seq Model
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(input_dim=word_vocab_size, output_dim=embedding_dim)(encoder_inputs)
encoder_lstm, state_h, state_c = LSTM(lstm_units, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(input_dim=pos_vocab_size, output_dim=embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(lstm_units, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(pos_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Compile the Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Prepare target data for training (shifted POS tags)
y_input = y[:, :-1]  # Input for decoder (excluding the last token)
y_output = y[:, 1:]  # Output for decoder (excluding the first token)
y_output = np.expand_dims(y_output, -1)  # Expand dimensions to match output shape

# Train the Model
model.fit([X, y_input], y_output, batch_size=32, epochs=10)

# Make Predictions
predictions = model.predict([X, y_input])
predicted_tags = np.argmax(predictions, axis=-1)

print("Predicted POS Tags:", predicted_tags)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 1.7932 - accuracy: 0.1111
# Epoch 2/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7858 - accuracy: 0.1111
# Epoch 3/10
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7784 - accuracy: 0.4444
# Epoch 4/10
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7710 - accuracy: 0.4444
# Epoch 5/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7634 - accuracy: 0.4444
# Epoch 6/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7555 - accuracy: 0.4444
# Epoch 7/10
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7474 - accuracy: 0.4444
# Epoch 8/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7389 - accuracy: 0.4444
# Epoch 9/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7300 - accuracy: 0.5556
# Epoch 10/10
# ...
# 1/1 [==============================] - 1s 656ms/step
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Reshape
from keras.layers import LeakyReLU
from keras.optimizers import Adam

# Load the MNIST dataset
(X_train, _), (_, _) = mnist.load_data()
X_train = (X_train.astype(np.float32) - 127.5) / 127.5  # Normalize images to [-1, 1]
X_train = X_train.reshape(X_train.shape[0], 28 * 28)  # Flatten images

# Define the Generator model
def build_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=100))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(28 * 28, activation='tanh'))
    model.add(Reshape((28, 28)))
    return model

# Define the Discriminator model
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation='sigmoid'))
    return model

# Compile and train the GAN
def build_and_train_gan(epochs=10000, batch_size=64):
    # Build and compile the Discriminator
    discriminator = build_discriminator()
    discriminator.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5), metrics=['accuracy'])

    # Build the Generator
    generator = build_generator()

    # The combined GAN model
    discriminator.trainable = False  # Freeze the Discriminator's weights
    gan = Sequential([generator, discriminator])
    gan.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5))

    # Training the GAN
    for epoch in range(epochs):
        # Training the Discriminator
        real_images = X_train[np.random.randint(0, X_train.shape[0], batch_size)]
        noise = np.random.normal(0, 1, (batch_size, 100))
        fake_images = generator.predict(noise)

        X = np.concatenate([real_images, fake_images])
        y = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])

        d_loss, d_acc = discriminator.train_on_batch(X, y)

        # Training the Generator
        noise = np.random.normal(0, 1, (batch_size, 100))
        y_gen = np.ones((batch_size, 1))  # The generator wants the discriminator to believe all images are real
        g_loss = gan.train_on_batch(noise, y_gen)

        # Print the progress every 1000 epochs
        if epoch % 1000 == 0:
            print(f"Epoch {epoch} - D Loss: {d_loss}, D Acc: {d_acc}, G Loss: {g_loss}")
            show_generated_images(generator)

# Function to display generated images
def show_generated_images(generator, examples=10):
    noise = np.random.normal(0, 1, (examples, 100))
    generated_images = generator.predict(noise)
    generated_images = 0.5 * generated_images + 0.5  # Rescale to [0, 1]

    plt.figure(figsize=(10, 2))
    for i in range(examples):
        plt.subplot(1, examples, i+1)
        plt.imshow(generated_images[i], cmap='gray')
        plt.axis('off')
    plt.show()

# Run the GAN training
build_and_train_gan()
# Out:
# 2/2 [==============================] - 0s 5ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6a5b6757c529> in <cell line: 88>()
#      86
#      87 # Run the GAN training
# ---> 88 build_and_train_gan()
#
# <ipython-input-5-6a5b6757c529> in build_and_train_gan(epochs, batch_size)
#      57         fake_images = generator.predict(noise)
#      58
# ---> 59         X = np.concatenate([real_images, fake_images])
#      60         y = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])
#      61
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 3 dimension(s)

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Reshape
from keras.layers import LeakyReLU
from keras.optimizers import Adam

# Load the MNIST dataset
(X_train, _), (_, _) = mnist.load_data()
X_train = (X_train.astype(np.float32) - 127.5) / 127.5  # Normalize images to [-1, 1]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)  # Reshape images to (28, 28, 1)

# Define the Generator model
def build_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=100))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(28 * 28 * 1, activation='tanh'))
    model.add(Reshape((28, 28, 1)))  # Reshape to (28, 28, 1)
    return model

# Define the Discriminator model
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28, 1)))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation='sigmoid'))
    return model

# Compile and train the GAN
def build_and_train_gan(epochs=10000, batch_size=64):
    # Build and compile the Discriminator
    discriminator = build_discriminator()
    discriminator.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5), metrics=['accuracy'])

    # Build the Generator
    generator = build_generator()

    # The combined GAN model
    discriminator.trainable = False  # Freeze the Discriminator's weights
    gan = Sequential([generator, discriminator])
    gan.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5))

    # Training the GAN
    for epoch in range(epochs):
        # Training the Discriminator
        real_images = X_train[np.random.randint(0, X_train.shape[0], batch_size)]
        noise = np.random.normal(0, 1, (batch_size, 100))
        fake_images = generator.predict(noise)

        # Ensure the fake images have the same shape as real images
        fake_images = fake_images.reshape(batch_size, 28, 28, 1)

        X = np.concatenate([real_images, fake_images])
        y = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])

        d_loss, d_acc = discriminator.train_on_batch(X, y)

        # Training the Generator
        noise = np.random.normal(0, 1, (batch_size, 100))
        y_gen = np.ones((batch_size, 1))  # The generator wants the discriminator to believe all images are real
        g_loss = gan.train_on_batch(noise, y_gen)

        # Print the progress every 1000 epochs
        if epoch % 1000 == 0:
            print(f"Epoch {epoch} - D Loss: {d_loss}, D Acc: {d_acc}, G Loss: {g_loss}")
            show_generated_images(generator)

# Function to display generated images
def show_generated_images(generator, examples=10):
    noise = np.random.normal(0, 1, (examples, 100))
    generated_images = generator.predict(noise)
    generated_images = 0.5 * generated_images + 0.5  # Rescale to [0, 1]

    plt.figure(figsize=(10, 2))
    for i in range(examples):
        plt.subplot(1, examples, i+1)
        plt.imshow(generated_images[i, :, :, 0], cmap='gray')
        plt.axis('off')
    plt.show()

# Run the GAN training
build_and_train_gan()

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Reshape, Flatten
from keras.layers import LeakyReLU
from keras.optimizers import Adam

# Load and preprocess the MNIST dataset
(X_train, _), (_, _) = mnist.load_data()
X_train = (X_train / 127.5) - 1.0  # Normalize images to [-1, 1]
X_train = X_train.reshape(-1, 28 * 28)  # Flatten images to 1D

# Build the Generator model
def build_generator():
    model = Sequential()
    model.add(Dense(128, input_dim=100))
    model.add(LeakyReLU(0.2))
    model.add(Dense(28 * 28, activation='tanh'))
    model.add(Reshape((28, 28)))
    return model

# Build the Discriminator model
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))
    model.add(Dense(128))
    model.add(LeakyReLU(0.2))
    model.add(Dense(1, activation='sigmoid'))
    return model

# Create and compile the models
generator = build_generator()
discriminator = build_discriminator()
discriminator.compile(optimizer=Adam(0.0002, 0.5), loss='binary_crossentropy', metrics=['accuracy'])

# Build the combined GAN model
discriminator.trainable = False  # Freeze the Discriminator during GAN training
gan = Sequential([generator, discriminator])
gan.compile(optimizer=Adam(0.0002, 0.5), loss='binary_crossentropy')

# Training the GAN
def train_gan(epochs=600, batch_size=64):
    for epoch in range(epochs):
        # Train the Discriminator
        real_images = X_train[np.random.randint(0, X_train.shape[0], batch_size)]
        real_images = real_images.reshape(batch_size, 28, 28)  # Reshape to 2D for Discriminator
        noise = np.random.normal(0, 1, (batch_size, 100))
        fake_images = generator.predict(noise)

        # Labels for real and fake images
        real_labels = np.ones((batch_size, 1))
        fake_labels = np.zeros((batch_size, 1))

        # Train on real and fake images
        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train the Generator
        noise = np.random.normal(0, 1, (batch_size, 100))
        labels = np.ones((batch_size, 1))  # We want the generator to trick the discriminator
        g_loss = gan.train_on_batch(noise, labels)

        # Display progress every 500 epochs
        if epoch % 500 == 0:
            print(f"Epoch {epoch} - D Loss: {d_loss[0]}, D Acc: {d_loss[1]}, G Loss: {g_loss}")
            show_generated_images(generator)

# Function to display generated images
def show_generated_images(generator, examples=5):
    noise = np.random.normal(0, 1, (examples, 100))
    generated_images = generator.predict(noise)
    generated_images = 0.5 * generated_images + 0.5  # Rescale images to [0, 1]

    plt.figure(figsize=(10, 2))
    for i in range(examples):
        plt.subplot(1, examples, i + 1)
        plt.imshow(generated_images[i], cmap='gray')
        plt.axis('off')
    plt.show()

# Train the GAN
train_gan()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Reshape, Flatten, Conv2D, Conv2DTranspose, LeakyReLU, Dropout
from tensorflow.keras.models import Sequential
import numpy as np
import matplotlib.pyplot as plt

# Generator model
def build_generator():
    model = Sequential()
    model.add(Dense(256 * 8 * 8, activation="relu", input_dim=100))
    model.add(Reshape((8, 8, 256)))
    model.add(Conv2DTranspose(128, kernel_size=4, strides=2, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Conv2DTranspose(64, kernel_size=4, strides=2, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Conv2D(1, kernel_size=7, activation='tanh', padding='same'))
    return model

# Discriminator model
def build_discriminator():
    model = Sequential()
    model.add(Conv2D(64, kernel_size=3, strides=2, input_shape=(32, 32, 1), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.3))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))
    return model

# GAN model
def build_gan(generator, discriminator):
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    return model

# Compile models
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
generator = build_generator()
discriminator.trainable = False
gan = build_gan(generator, discriminator)
gan.compile(loss='binary_crossentropy', optimizer='adam')

# Training function
def train_gan(gan, generator, discriminator, epochs=10000, batch_size=128):
    (x_train, _), (_, _) = tf.keras.datasets.mnist.load_data()
    x_train = (x_train - 127.5) / 127.5  # Normalize to [-1, 1]
    x_train = np.expand_dims(x_train, axis=-1)
    x_train = tf.image.resize(x_train, [32, 32]).numpy()  # Resize and convert to numpy array
    for epoch in range(epochs):
        idx = np.random.randint(0, x_train.shape[0], batch_size)
        real_imgs = x_train[idx]
        noise = np.random.normal(0, 1, (batch_size, 100))
        fake_imgs = generator.predict(noise)
        d_loss_real = discriminator.train_on_batch(real_imgs, np.ones((batch_size, 1)))
        d_loss_fake = discriminator.train_on_batch(fake_imgs, np.zeros((batch_size, 1)))
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        noise = np.random.normal(0, 1, (batch_size, 100))
        valid_y = np.ones((batch_size, 1))
        g_loss = gan.train_on_batch(noise, valid_y)
        if epoch % 1000 == 0:
            print(f"{epoch} [D loss: {d_loss[0]}, acc.: {100*d_loss[1]}] [G loss: {g_loss}]")
            save_images(generator)

def save_images(generator, noise_input=100, grid_size=(5, 5)):
    noise = np.random.normal(0, 1, (grid_size[0] * grid_size[1], noise_input))
    generated_images = generator.predict(noise)
    generated_images = 0.5 * generated_images + 0.5  # Rescale to [0, 1]
    fig, axs = plt.subplots(grid_size[0], grid_size[1], figsize=(grid_size[0], grid_size[1]), sharey=True, sharex=True)
    count = 0
    for i in range(grid_size[0]):
        for j in range(grid_size[1]):
            axs[i, j].imshow(generated_images[count, :, :, 0], cmap='gray')
            axs[i, j].axis('off')
            count += 1
    plt.show()

# Train the GAN
train_gan(gan, generator, discriminator, epochs=10000, batch_size=128)
# Out:
# 4/4 [==============================] - 0s 27ms/step
# 0 [D loss: 0.7469660043716431, acc.: 2.34375] [G loss: 0.6883347034454346]
# ...
# 4/4 [==============================] - 0s 26ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f0f86bbac0c0> in <cell line: 82>()
#      80
#      81 # Train the GAN
# ---> 82 train_gan(gan, generator, discriminator, epochs=10000, batch_size=128)
#
# <ipython-input-8-f0f86bbac0c0> in train_gan(gan, generator, discriminator, epochs, batch_size)
#      61         noise = np.random.normal(0, 1, (batch_size, 100))
#      62         valid_y = np.ones((batch_size, 1))
# ---> 63         g_loss = gan.train_on_batch(noise, valid_y)
#      64         if epoch % 1000 == 0:
#      65             print(f"{epoch} [D loss: {d_loss[0]}, acc.: {100*d_loss[1]}] [G loss: {g_loss}]")
#
# ...

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load the MNIST dataset
(x_train, _), (_, _) = tf.keras.datasets.mnist.load_data()

# Display the first 9 images from the training dataset
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.axis('off')
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')

# Visualize results
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'
    plt.xlabel(f"Predicted: {predicted_label} ({color})", color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)
    thisplot[predicted_label].set_color('red')
    thisplot[true_label[0]].set_color('blue')

# Predict on test images
predictions = model.predict(x_test)

# Plot the first 25 test images, their predicted labels, and the true labels
num_rows, num_cols = 5, 5
num_images = num_rows * num_cols
plt.figure(figsize=(2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions, y_test, x_test)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, y_test)
plt.tight_layout()
plt.show()
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step
# Epoch 1/10
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.5007 - accuracy: 0.4606 - val_loss: 1.2309 - val_accuracy: 0.5632
# Epoch 2/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1684 - accuracy: 0.5884 - val_loss: 1.0908 - val_accuracy: 0.6179
# Epoch 3/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.0405 - accuracy: 0.6370 - val_loss: 1.0656 - val_accuracy: 0.6263
# Epoch 4/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.9650 - accuracy: 0.6648 - val_loss: 1.0020 - val_accuracy: 0.6508
# Epoch 5/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.9063 - accuracy: 0.6861 - val_loss: 0.9512 - val_accuracy: 0.6728
# Epoch 6/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8531 - accuracy: 0.7045 - val_loss: 0.9763 - val_accuracy: 0.6613
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# Class names for CIFAR-10 dataset
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')

# Visualize results
def plot_image_with_label(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'
    plt.xlabel(f"Predicted: {class_names[predicted_label]}\n(True: {class_names[true_label[0]]})", color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)
    thisplot[predicted_label].set_color('red')
    thisplot[true_label[0]].set_color('blue')

# Predict on test images
predictions = model.predict(x_test)

# Plot the first 25 test images, their predicted labels, and the true labels
num_rows, num_cols = 5, 5
num_images = num_rows * num_cols
plt.figure(figsize=(2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image_with_label(i, predictions, y_test, x_test)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, y_test)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.4474 - accuracy: 0.4826 - val_loss: 1.1963 - val_accuracy: 0.5829
# Epoch 2/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0792 - accuracy: 0.6228 - val_loss: 1.0150 - val_accuracy: 0.6430
# Epoch 3/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9510 - accuracy: 0.6665 - val_loss: 0.9881 - val_accuracy: 0.6508
# Epoch 4/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8697 - accuracy: 0.6955 - val_loss: 0.9307 - val_accuracy: 0.6822
# Epoch 5/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.8057 - accuracy: 0.7175 - val_loss: 0.9077 - val_accuracy: 0.6859
# Epoch 6/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7484 - accuracy: 0.7401 - val_loss: 0.9167 - val_accuracy: 0.6881
# Epoch 7/10
# ...
